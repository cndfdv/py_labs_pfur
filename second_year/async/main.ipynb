# %% [markdown]
# ### 1
# ____

# %%
from task1_sync import task1_sync_calculations

task1_sync_calculations()
# Out:
# Начало операции 15 + 25
# Конец операции 15 + 25 = 40
# Начало операции 40 - 18
# Конец операции 15 + 25 = 40
# Начало операции 40 - 18
# Конец операции 40 - 18 = 22
# Начало операции 12 * 8
# Конец операции 40 - 18 = 22
# Начало операции 12 * 8
# Конец операции 12 * 8 = 96
# Начало операции 100 / 5
# Конец операции 12 * 8 = 96
# Начало операции 100 / 5
# Конец операции 100 / 5 = 20.0
# Общее время выполнения: 7.02 секунд
# Результаты: [40, 22, 96, 20.0]
# Конец операции 100 / 5 = 20.0
# Общее время выполнения: 7.02 секунд
# Результаты: [40, 22, 96, 20.0]

# %% [markdown]
# ### 2
# ____

# %%
from task2_threading import task2_threaded_downloader

task2_threaded_downloader()
# Out:
# Начало загрузки document.pdf (10 МБ)Начало загрузки image.jpg (5 МБ)
#
# Начало загрузки video.mp4 (20 МБ)
# Начало загрузки archive.zip (15 МБ)
# image.jpg: 20% загружено
# document.pdf: 20% загружено
# image.jpg: 40% загружено
# archive.zip: 20% загружено
# image.jpg: 60% загружено
# document.pdf: 20% загружено
# image.jpg: 40% загружено
# archive.zip: 20% загружено
# image.jpg: 60% загружено
# video.mp4: 20% загруженоdocument.pdf: 40% загружено
#
# image.jpg: 80% загружено
# image.jpg: 100% загружено
# Завершена загрузка image.jpg
# document.pdf: 60% загружено
# video.mp4: 20% загруженоdocument.pdf: 40% загружено
#
# image.jpg: 80% загружено
# image.jpg: 100% загружено
# Завершена загрузка image.jpg
# document.pdf: 60% загружено
# archive.zip: 40% загружено
# video.mp4: 40% загружено
# document.pdf: 80% загружено
# archive.zip: 40% загружено
# video.mp4: 40% загружено
# document.pdf: 80% загружено
# archive.zip: 60% загружено
# document.pdf: 100% загружено
# ...

# %% [markdown]
# ### 3
# ____

# %% [markdown]
# #### запускать сам файл, юпитер ломает чето

# %%
# !python task3_multiprocessing.py
# Out:
# === МНОГОПРОЦЕССНОЕ ВЫПОЛНЕНИЕ (Pool) ===
# Начало вычисления факториала 50000!
# Начало вычисления факториала 80000!
# Начало проверки числа 1000019 на простоту
# Число 1000019 простое: False
# Начало проверки числа 1000033 на простоту
# Число 1000033 простое: True
# Начало вычисления факториала 50000!
# Начало вычисления факториала 80000!
# Начало проверки числа 1000019 на простоту
# Число 1000019 простое: False
# Начало проверки числа 1000033 на простоту
# Число 1000033 простое: True
# Завершено вычисление факториала 50000! = ...Завершено вычисление факториала 50000! = ...
# ...
# Завершено вычисление факториала 80000! = ...Завершено вычисление факториала 80000! = ...
#
# === СИНХРОННОЕ ВЫПОЛНЕНИЕ ===
# Начало вычисления факториала 50000!
# ...
#
# === СИНХРОННОЕ ВЫПОЛНЕНИЕ ===
# Начало вычисления факториала 50000!
# Завершено вычисление факториала 50000! = ...Завершено вычисление факториала 50000! = ...
# Начало вычисления факториала 80000!
# ...
# ...

# %% [markdown]
# ### 4
# ___

# %%
from task4_async_scraper import task4_async_scraper
import asyncio

await task4_async_scraper()
# Out:
# Начало загрузки Сайт 1
# Начало загрузки Сайт 2
# Начало загрузки Сайт 3
# Начало загрузки Сайт 4
# Завершена загрузка Сайт 1, статус: 200
# Завершена загрузка Сайт 1, статус: 200
# Завершена загрузка Сайт 4, статус: 200
# Завершена загрузка Сайт 4, статус: 200
# Завершена загрузка Сайт 3, статус: 503
# Завершена загрузка Сайт 3, статус: 503
# Завершена загрузка Сайт 2, статус: 503
# Общее время выполнения: 62.13 секунд
# Размеры контента: [365, 162, 162, 365]
# Завершена загрузка Сайт 2, статус: 503
# Общее время выполнения: 62.13 секунд
# Размеры контента: [365, 162, 162, 365]

# %% [markdown]
# ### 5
# ____

# %%
# !python task5_performance.py
# Out:
# Синхронное время:        9.02 сек
# Многопоточное время:    3.00 сек
# Многопроцессное время:  3.13 сек
# Асинхронное время:      3.00 сек

# %% [markdown]
# ### 6
# ____

# %%
from task6_scheduler import task6_async_scheduler
import asyncio

await task6_async_scheduler()
# Out:
# [04:39:15] Задача 'Экстренная задача' (приоритет 1) начата
# [04:39:15] Задача 'Важная задача' (приоритет 2) начата
# [04:39:16] Задача 'Экстренная задача' завершена
# [04:39:16] Задача 'Обычная задача A' (приоритет 3) начата
# [04:39:16] Получен результат: Результат Экстренная задача
# [04:39:16] Задача 'Экстренная задача' завершена
# [04:39:16] Задача 'Обычная задача A' (приоритет 3) начата
# [04:39:16] Получен результат: Результат Экстренная задача
# [04:39:17] Задача 'Важная задача' завершена
# [04:39:17] Задача 'Обычная задача B' (приоритет 3) начата
# [04:39:17] Получен результат: Результат Важная задача
# [04:39:17] Задача 'Важная задача' завершена
# [04:39:17] Задача 'Обычная задача B' (приоритет 3) начата
# [04:39:17] Получен результат: Результат Важная задача
# [04:39:19] Задача 'Обычная задача B' завершена
# [04:39:19] Задача 'Обычная задача A' завершена
# [04:39:19] Задача 'Фоновая задача' (приоритет 4) начата
# [04:39:19] Получен результат: Результат Обычная задача B
# ...

# %% [markdown]
# ### 7
# ____

# %%
from task7_idk import task7_thread_pool

task7_thread_pool()
# Out:
# >>> Пул из 2 потоков
# Обработан элемент 2 -> 4 (время: 1.17с)
# Обработан элемент 1 -> 2 (время: 1.18с)
# Обработан элемент 2 -> 4 (время: 1.17с)
# Обработан элемент 1 -> 2 (время: 1.18с)
# Обработан элемент 3 -> 6 (время: 1.21с)
# Обработан элемент 3 -> 6 (время: 1.21с)
# Обработан элемент 4 -> 8 (время: 1.69с)
# Обработан элемент 4 -> 8 (время: 1.69с)
# Обработан элемент 6 -> 12 (время: 1.01с)
# Обработан элемент 5 -> 10 (время: 1.64с)
# Обработан элемент 6 -> 12 (время: 1.01с)
# Обработан элемент 5 -> 10 (время: 1.64с)
# Обработан элемент 7 -> 14 (время: 0.89с)
# Обработан элемент 7 -> 14 (время: 0.89с)
# Обработан элемент 8 -> 16 (время: 2.00с)
# Обработан элемент 8 -> 16 (время: 2.00с)
# Обработан элемент 9 -> 18 (время: 1.62с)
# Обработан элемент 9 -> 18 (время: 1.62с)
# Обработан элемент 10 -> 20 (время: 1.70с)
#
# >>> Пул из 4 потоков
# Обработан элемент 10 -> 20 (время: 1.70с)
#
# >>> Пул из 4 потоков
# Обработан элемент 4 -> 8 (время: 0.55с)
# ...
